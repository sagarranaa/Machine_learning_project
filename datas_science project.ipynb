# %% [markdown]
# ###### import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("StatewiseTestingDetails.csv")
df.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
df.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
df.tail()
# Out:
#             Date        State  TotalSamples Negative  Positive
# 8061  2020-12-04  West Bengal     6047279.0      NaN       NaN
# 8062  2020-12-05  West Bengal     6091668.0      NaN       NaN
# 8063  2020-12-06  West Bengal     6135854.0      NaN       NaN
# 8064  2020-12-07  West Bengal     6167307.0      NaN       NaN
# 8065  2020-12-08  West Bengal     6211537.0      NaN       NaN

# %%
df.describe()
# Out:
#        TotalSamples      Positive
# count  8.066000e+03  4.866000e+03
# mean   1.503140e+06  4.317863e+04
# std    2.709261e+06  1.536970e+05
# min    5.800000e+01  0.000000e+00
# 25%    4.659300e+04  3.632500e+02
# 50%    2.604005e+05  2.928500e+03
# 75%    1.780533e+06  2.223100e+04
# max    2.062145e+07  1.638961e+06

# %%
df.isnull().sum()
# Out:
# Date               0
# State              0
# TotalSamples       0
# Negative        3772
# Positive        3200
# dtype: int64

# %% [markdown]
# ##### Relating the variables with scatter plot

# %%
sns.relplot(x='Positive',y='TotalSamples',data=df)

# %%
sns.relplot(x='Positive',y='TotalSamples',hue='State',data=df)

# %%
sns.pairplot(df)

# %%
sns.catplot(x='Positive',y='TotalSamples',data=df)
